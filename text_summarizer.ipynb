# %%
# !pip install transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 15.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 22.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 38.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 40.6 MB/s eta 0:00:00
# ...

# %%
from transformers import pipeline

# %%
summariser=pipeline("summarization")
# Out:
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 and revision a4f8f3e (https://huggingface.co/sshleifer/distilbart-cnn-12-6).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# ...

# %%
article="""Geek Room at Maharaja Surajmal Institute of Technology is dedicated to fostering a vibrant coding culture within our college campus. We believe that coding is a fundamental skill that transcends traditional boundaries, and we are committed to instilling this belief in our fellow students. Here are some key highlights of our efforts:

1. **Coding Culture**: Our primary objective is to cultivate a strong coding culture within our college. We aim to make coding not just an academic requirement but a way of thinking and problem-solving that extends to various domains and disciplines.

2. **Inclusivity**: Geek Room is an inclusive community where students of all backgrounds and experiences are welcome. We strive to create an environment where everyone, regardless of their prior coding knowledge, feels comfortable and encouraged to learn and grow.

3. **Skill Enhancement**: We offer resources and opportunities for skill enhancement. Through workshops, seminars, and coding competitions, we empower our members to continually improve their coding abilities and stay updated with the latest developments in technology.

4. **Teamwork and Collaboration**: Coding is often a collaborative effort, and we emphasize teamwork. Our hackathons and team-based coding competitions provide a platform for students to work together, share ideas, and learn from one another.

5. **Cross-Disciplinary Learning**: We believe that coding is not limited to computer science alone. We encourage students from various disciplines to explore coding in their respective fields, bridging the gap between technology and other domains.

6. **Nationwide Ecosystem**: As we expand our reach, we aim to create a nationwide ecosystem that promotes coding and technology literacy. This ecosystem will not only benefit our members within the college but also connect them with peers and resources from other reputed institutions.

Geek Room at Maharaja Surajmal Institute of Technology is more than just a club; it's a driving force behind the cultivation of coding skills and the promotion of technological innovation within our college. We are dedicated to nurturing a coding culture that prepares students for the challenges and opportunities of the digital age. Join us in our mission to learn, create, and inspire."""

# %%
summariser(article,max_length=200,min_length=50,do_sample=False)
# Out:
# [{'summary_text': ' Geek Room at Maharaja Surajmal Institute of Technology is dedicated to fostering a vibrant coding culture within our college campus . We aim to make coding not just an academic requirement but a way of thinking and problem-solving that extends to various domains and disciplines . Geek Room is an inclusive community where students of all backgrounds and experiences are welcome .'}]
